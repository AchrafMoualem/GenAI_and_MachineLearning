# %% [markdown]
# # Daily Challenge: Data Handling and Analysis in Python

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE

# %%
df = pd.read_csv('datascience_salaries.csv')

# %%
df.head()
# Out:
#    Unnamed: 0       job_title   job_type experience_level       location  \
# 0           0  Data scientist  Full Time           Senior  New York City
# 1           2  Data scientist  Full Time           Senior         Boston
# 2           3  Data scientist  Full Time           Senior         London
# 3           4  Data scientist  Full Time           Senior         Boston
# 4           5  Data scientist  Full Time           Senior  New York City
#
#   salary_currency  salary
# 0             USD  149000
# 1             USD  120000
# 2             USD   68000
# 3             USD  120000
# 4             USD  149000

# %%
# data normalization with min-max scaler

scaler = MinMaxScaler()
df['salary'] = scaler.fit_transform(df[['salary']])

# %%
df.head()
# Out:
#    Unnamed: 0       job_title   job_type experience_level       location  \
# 0           0  Data scientist  Full Time           Senior  New York City
# 1           2  Data scientist  Full Time           Senior         Boston
# 2           3  Data scientist  Full Time           Senior         London
# 3           4  Data scientist  Full Time           Senior         Boston
# 4           5  Data scientist  Full Time           Senior  New York City
#
#   salary_currency    salary
# 0             USD  0.601010
# 1             USD  0.454545
# 2             USD  0.191919
# 3             USD  0.454545
# 4             USD  0.601010

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Data scientist      394
# Data analyst        368
# Machine learning    289
# Big data            101
# ML Ops               19
# Name: count, dtype: int64

# %%
df = df.drop(columns=["Unnamed: 0"])

# %%
df.head()
# Out:
#         job_title   job_type experience_level       location salary_currency  \
# 0  Data scientist  Full Time           Senior  New York City             USD
# 1  Data scientist  Full Time           Senior         Boston             USD
# 2  Data scientist  Full Time           Senior         London             USD
# 3  Data scientist  Full Time           Senior         Boston             USD
# 4  Data scientist  Full Time           Senior  New York City             USD
#
#      salary  job_title_enc
# 0  0.601010              2
# 1  0.454545              2
# 2  0.191919              2
# 3  0.454545              2
# 4  0.601010              2

# %%
X = df.drop(columns=["salary"])

# %%
import pandas as pd

X_encoded = pd.get_dummies(X)

# %%
X_encoded.head()
# Out:
#    job_title_enc  job_title_Big data  job_title_Data analyst  \
# 0              2               False                   False
# 1              2               False                   False
# 2              2               False                   False
# 3              2               False                   False
# 4              2               False                   False
#
#    job_title_Data scientist  job_title_ML Ops  job_title_Machine learning  \
# 0                      True             False                       False
# 1                      True             False                       False
# 2                      True             False                       False
# 3                      True             False                       False
# 4                      True             False                       False
#
#    job_type_Full Time  job_type_Internship  experience_level_Entry  \
# 0                True                False                   False
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_tsne_scaled = scaler.fit_transform(X_tsne)

# %%
# dimensionality reduction with t-SNE

tsne = TSNE(
    n_components=2,
    perplexity=30,
    learning_rate=200,
    random_state=42
)

X_tsne = tsne.fit_transform(X_tsne_scaled)

# %%
salary_by_exp = df.groupby('experience_level')['salary'].agg(['mean', 'median', 'count'])
print(salary_by_exp)
# Out:
#                       mean    median  count
# experience_level
# Entry             0.030864  0.000000    126
# Executive         0.232712  0.080808     13
# Mid               0.110035  0.106061    305
# Senior            0.227717  0.191919    727
